# %% [markdown]
# # Automated Georeferencing

# %%
import subprocess

import cv2
import matplotlib.pyplot as plt


import rasterio as rio
from rasterio.transform import from_gcps
from rasterio.control import GroundControlPoint

from historef.center import get_fiducial_mark_centers
from historef.grid import *
from historef.transform import find_overlapping_transform, apply_transform_points, find_nearest_pairs
from historef.util import intensity_cut
from historef import matchraster

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Step 1. Extract Fiducial Marks and construct grid graph
#
# Preprocessing matters.
# * intensity cut really helps to reduce fals positive detection of fiducial mark in histology.
# * removing blackened region in histology matters in calculating raster differences.

# %%
ngef  = "../sample/b04d/N3-HG5MC.B04D.human.sge_match_sbcd.png"   ## nbcd-nmatch-nge 3way image
im_nge_raw = cv2.imread(ngef, cv2.IMREAD_COLOR)
im_nge = matchraster.preprocess_image(im_nge_raw, channel=0, xy_swap=True)
circles_sbcd, im_matched = get_fiducial_mark_centers(im_nge, 'sbcd', min_dist = 200)
v_sbcd, e_sbcd = construct_grid_graph(circles_sbcd)
plot_edges(v_sbcd, e_sbcd)
# Out:
# /Users/yonghah/repo/historef/historef/template/fiducial_mark.sbcd.png
# detected 384 fiducial marks and skipped 0

# %%
hnef = "../sample/b04d/B04D_10X_crop.tif" 
im_hne_raw = cv2.imread(hnef, cv2.IMREAD_COLOR)
im_hne = intensity_cut(im_hne_raw)
im_hne = matchraster.preprocess_image(im_hne, xy_swap=True)
circles_hist, _ = get_fiducial_mark_centers(im_hne, 'HnE', min_dist = 300)
v_hist, e_hist = construct_grid_graph(circles_hist)
plot_edges(v_hist, e_hist)
# Out:
# /Users/yonghah/repo/historef/historef/template/fiducial_mark.HnE.png
# Skipped a fiducial mark at (718, 6323) with (169, 831)
# Skipped a fiducial mark at (641, 5631) with (169, 937)
# Skipped a fiducial mark at (1073, 6641) with (169, 1314)
# Skipped a fiducial mark at (1956, 3599) with (168, 316)
# Skipped a fiducial mark at (1190, 6269) with (169, 509)
# Skipped a fiducial mark at (2034, 1040) with (54, 66)
# Skipped a fiducial mark at (882, 5961) with (169, 1162)
# Skipped a fiducial mark at (1541, 6688) with (163, 248)
# Skipped a fiducial mark at (973, 1022) with (50, 74)
# Skipped a fiducial mark at (5090, 1090) with (52, 139)
# Skipped a fiducial mark at (1694, 6183) with (167, 302)
# Skipped a fiducial mark at (5083, 1501) with (51, 201)
# Skipped a fiducial mark at (3269, 1835) with (169, 408)
# Skipped a fiducial mark at (6605, 1937) with (48, 72)
# Skipped a fiducial mark at (5077, 1912) with (50, 159)
# Skipped a fiducial mark at (4023, 1483) with (52, 106)
# Skipped a fiducial mark at (5550, 1508) with (50, 68)
# Skipped a fiducial mark at (2488, 1869) with (51, 63)
# Skipped a fiducial mark at (5557, 1098) with (50, 51)
# Skipped a fiducial mark at (2365, 7225) with (169, 1255)
# Skipped a fiducial mark at (3563, 1065) with (49, 500)
# Skipped a fiducial mark at (731, 4293) with (166, 635)
# Skipped a fiducial mark at (2501, 1048) with (47, 90)
# Skipped a fiducial mark at (6612, 1527) with (50, 117)
# Skipped a fiducial mark at (1988, 7103) with (169, 986)
# Skipped a fiducial mark at (3556, 1475) with (51, 119)
# Skipped a fiducial mark at (927, 3898) with (44, 51)
# Skipped a fiducial mark at (1967, 5148) with (48, 251)
# Skipped a fiducial mark at (5544, 1919) with (43, 82)
# Skipped a fiducial mark at (4030, 1072) with (41, 218)
# Skipped a fiducial mark at (2468, 3101) with (44, 315)
# Skipped a fiducial mark at (907, 5131) with (42, 334)
# Skipped a fiducial mark at (2454, 3923) with (44, 140)
# Skipped a fiducial mark at (2495, 1459) with (38, 90)
# Skipped a fiducial mark at (1981, 4327) with (41, 64)
# Skipped a fiducial mark at (2441, 4746) with (46, 158)
# Skipped a fiducial mark at (914, 4721) with (38, 112)
# Skipped a fiducial mark at (2372, 3455) with (126, 426)
# Skipped a fiducial mark at (1498, 4518) with (147, 122)
# Skipped a fiducial mark at (1479, 5055) with (160, 354)
# Skipped a fiducial mark at (2832, 1058) with (121, 166)
# Skipped a fiducial mark at (2142, 3906) with (153, 92)
# Skipped a fiducial mark at (5051, 3553) with (37, 99)
# Skipped a fiducial mark at (1687, 7047) with (146, 273)
# Skipped a fiducial mark at (3654, 6920) with (157, 143)
# Skipped a fiducial mark at (1637, 5368) with (116, 88)
# Skipped a fiducial mark at (5050, 3107) with (91, 83)
# Skipped a fiducial mark at (1671, 1338) with (144, 254)
# Skipped a fiducial mark at (8541, 5667) with (10, 0)
# detected 90 fiducial marks and skipped 49

# %% [markdown]
# We are going to identify scale factor and rotation with the grid graphs.
#
# ### identify scale factor
# When we examine the lengths of the edges in grid graph, there should be two prominent peaks: horizontal edges and vertical edges. We are going to find scale factor by comparing the shorter peaks from the two graphs.

# %%
scale_factor, xgrid_sbcd, xgrid_hist = identify_scale_factor(e_sbcd, e_hist)
# Out:
# xgrid_1 / xgrid_2:: 315.5 / 411.5 = 0.7667071688942891

# %% [markdown]
# ### Rotation
# We are going to identify the proper rotation angle by minimizizng the error to the cardinal directions based on the assumption that sbcds are aligned to the cardinal direction.

# %%
rotation = identify_rotation_angle(e_hist)
# Out:
# Rotation Angle -0.8832583902745024

# %% [markdown]
# ## Step 2. Find Candidate Transform and find best transform
# Since we found rotation and scale, we need to find translation. We have limited possibility of translation since it can be limted to (V in histology graph) X (V in sbcd graph). Moreover, the possible translations are limited to the translation that bbox of histology falls inside to the bbox of sbcd.

# %%
tms, avg_distances = find_overlapping_transform(v_sbcd, v_hist, rotation, scale_factor, max_nearest=0.33*xgrid_sbcd)
print("Number of candidates:", len(tms))
# example
v_tf = apply_transform_points(v_hist, tms[100])
plot_edges(v_tf, e_sbcd)
# Out:
# Number of candidates: 2043

# %%
plt.figure(figsize=(10, 6))
plt.hist(avg_distances, bins=100)  
plt.show()

# %% [markdown]
# For each transform, we apply the transform to the histology image and compare the transformed image's red channel (mostly tissue)  with sbcd's red channel (the matched barcodes).
#
# Before doing that, we need preprocess images
# - make grayscale
# - set blur
# - gamma

# %%
sbcd_lvl = matchraster.preprocess_image(im_nge_raw, xy_swap=True, channel=1, blur=1, gamma=5)
plt.figure(figsize=(15, 15))
plt.imshow(sbcd_lvl, cmap='Greys')

# %%
hist_green = matchraster.preprocess_image(im_hne_raw, xy_swap=True, channel=1, blur=None, gamma=3)
plt.figure(figsize=(10, 10))
plt.imshow(hist_green, cmap='Greys')

# %%
best_tf, best_idx, best_B, errors  = matchraster.find_best_transform(sbcd_lvl, hist_green, tms)
# Out:
# 0
# 500
# 1000
# 1500
# 2000
# Best Transform: 1210 (37.86435524678133)

# %%
plt.figure(figsize=(20, 6))
plt.hist(errors, bins=1000)  
plt.show()

# %%
hist_match = cv2.warpAffine(hist_green, best_tf[:2, :], (sbcd_lvl.shape[1], sbcd_lvl.shape[0]))
zeros = np.zeros(sbcd_lvl.shape[:2], dtype="uint8")
merged = cv2.merge([sbcd_lvl, hist_match , zeros])  
plt.figure(figsize = (20,15))
plt.imshow(merged)

# %%
v_tf = apply_transform_points(v_hist, tms[best_idx])
plot_edges(v_tf, e_sbcd)

# %% [markdown]
# ## Step3. Find GCP pairs

# %%
pairs = find_nearest_pairs(v_sbcd, v_hist, tms[best_idx], threshold=100)
print(len(v_tf), len(pairs))
# Out:
# 130 114

# %%
plt.figure(figsize=(10, 6))
plt.hist([m[3] for m in pairs], bins=100)
plt.xlabel("Distance between matched marks")
plt.show()

# %% [markdown]
# We are going to finally georeference the histology using the paired matches  as ground control points.

# %%
def gcps_from_pairs(match_pairs, rasterio=False, xy_swap=False, y_flip=False):
    gcps = []
    for p in match_pairs:
        target_x = p[2][1] if xy_swap else p[2][0]
        target_y = p[2][0] if xy_swap else p[2][1]
        target_y = -target_y if y_flip else target_y
        gcp = (p[0][1], p[0][0], target_x, target_y)
        if rasterio:
            gcps.append(GroundControlPoint(*gcp))
        else:
            gcps.append(gcp)
    return gcps

# %%
# this uses affine transform from gcps. Not very accurate compared to tps
gcps = gcps_from_pairs(pairs, rasterio=True, xy_swap=False, y_flip=False)
updated_file = "../sample/histology-3857-aligned_ff.tif" 
gcp_transform = from_gcps(gcps)
with rio.open(hnef, 'r+') as src:
    data = src.read()
    new_meta = src.meta.copy()
    new_meta.update({
        "crs": "EPSG:3857",
        "transform": gcp_transform
    })
    
    with rio.open(updated_file, 'w', **new_meta) as dst:
        dst.write(data)

# %%
def execute_gdal_translate(gcps, input_file, output_file):
    # Build the gdal_translate command with -gcp options
    cmd = ['gdal_translate']
    
    for gcp in gcps:
        cmd.extend(['-gcp', str(gcp[0]), str(gcp[1]), str(gcp[2]), str(gcp[3])])
    
    cmd.extend(['-a_srs', 'epsg:3857', input_file, output_file])
    
    try:
        # Execute the command
        subprocess.run(cmd, check=True)
        print("gdal_translate executed successfully.")
    except subprocess.CalledProcessError as e:
        print(f"Error executing gdal_translate: {e}")

def execute_gdalwarp(input_file, output_file):
    # Build the gdal_translate command with -gcp options
    cmd = ['gdalwarp']
    
    cmd.extend(['-order 2', input_file, output_file])
    
    try:
        # Execute the command
        print(" ".join(cmd))
        subprocess.run(cmd, check=True)
        print("gdal_translate executed successfully.")
    except subprocess.CalledProcessError as e:
        print(f"Error executing gdal_translate: {e}")

# %%
gcps = gcps_from_pairs(pairs)
input_file = hnef
translate_file = "../sample/b04d/histology_translated.tif" 
warp_file = "../sample/b04d/histology_aligned.tif" 
execute_gdal_translate(gcps, input_file, translate_file)
execute_gdalwarp(translate_file, warp_file)
# Out:
# Error executing gdal_translate: Command '['gdal_translate', '-gcp', '5124', '440', '347', '7061', '-gcp', '4713', '447', '347', '6746', '-gcp', '3891', '461', '347', '6116', '-gcp', '3481', '467', '347', '5801', '-gcp', '3070', '473', '347', '5486', '-gcp', '2657', '478', '347', '5170', '-gcp', '2248', '486', '347', '4855', '-gcp', '1835', '493', '347', '4541', '-gcp', '1425', '499', '347', '4226', '-gcp', '7186', '873', '704', '8636', '-gcp', '3887', '892', '704', '6116', '-gcp', '5131', '907', '704', '7061', '-gcp', '4721', '914', '704', '6746', '-gcp', '3487', '934', '704', '5801', '-gcp', '3077', '940', '704', '5486', '-gcp', '2666', '946', '704', '5170', '-gcp', '2255', '953', '704', '4855', '-gcp', '1844', '959', '704', '4541', '-gcp', '1433', '966', '704', '4226', '-gcp', '1022', '973', '704', '3910', '-gcp', '7203', '1935', '1514', '8635', '-gcp', '4747', '1938', '1514', '6745', '-gcp', '3599', '1956', '1514', '5801', '-gcp', '5148', '1967', '1514', '7061', '-gcp', '4327', '1981', '1514', '6431', '-gcp', '3094', '2001', '1515', '5486', '-gcp', '2683', '2007', '1515', '5171', '-gcp', '2272', '2014', '1515', '4855', '-gcp', '1862', '2020', '1515', '4540', '-gcp', '1451', '2027', '1515', '4226', '-gcp', '1040', '2034', '1514', '3911', '-gcp', '7225', '2365', '1871', '8635', '-gcp', '3503', '2412', '1872', '5801', '-gcp', '4746', '2441', '1871', '6745', '-gcp', '4335', '2448', '1871', '6431', '-gcp', '3923', '2454', '1872', '6115', '-gcp', '3101', '2468', '1872', '5485', '-gcp', '2691', '2475', '1872', '5171', '-gcp', '2280', '2482', '1872', '4855', '-gcp', '1869', '2488', '1872', '4540', '-gcp', '1459', '2495', '1872', '4226', '-gcp', '1048', '2501', '1872', '3911', '-gcp', '6406', '3477', '2683', '8006', '-gcp', '5585', '3489', '2683', '7376', '-gcp', '4352', '3510', '2683', '6430', '-gcp', '3529', '3523', '2683', '5801', '-gcp', '2708', '3537', '2683', '5170', '-gcp', '2297', '3543', '2683', '4855', '-gcp', '1065', '3563', '2684', '3910', '-gcp', '5962', '3952', '3040', '7691', '-gcp', '4360', '3977', '3040', '6430', '-gcp', '3949', '3984', '3040', '6116', '-gcp', '3538', '3991', '3040', '5801', '-gcp', '2305', '4011', '3040', '4855', '-gcp', '1894', '4017', '3040', '4541', '-gcp', '1483', '4023', '3040', '4226', '-gcp', '1072', '4030', '3041', '3910', '-gcp', '6030', '4977', '3850', '7691', '-gcp', '3107', '5050', '3851', '5486', '-gcp', '3553', '5051', '3851', '5801', '-gcp', '2322', '5071', '3851', '4855', '-gcp', '1912', '5077', '3851', '4540', '-gcp', '1501', '5083', '3851', '4226', '-gcp', '1090', '5090', '3851', '3911', '-gcp', '7262', '5460', '4208', '8635', '-gcp', '2741', '5531', '4208', '5171', '-gcp', '2330', '5538', '4208', '4855', '-gcp', '1919', '5544', '4208', '4540', '-gcp', '1508', '5550', '4208', '4226', '-gcp', '1098', '5557', '4208', '3911', '-gcp', '6046', '6539', '5017', '7690', '-gcp', '5634', '6547', '5017', '7376', '-gcp', '5224', '6553', '5017', '7061', '-gcp', '4813', '6559', '5017', '6746', '-gcp', '4402', '6566', '5017', '6431', '-gcp', '3170', '6585', '5017', '5486', '-gcp', '2757', '6593', '5017', '5170', '-gcp', '2347', '6600', '5017', '4855', '-gcp', '1937', '6605', '5017', '4541', '-gcp', '1527', '6612', '5017', '4226', '-gcp', '1115', '6619', '5017', '3910', '-gcp', '6875', '6993', '5374', '8321', '-gcp', '6465', '6999', '5374', '8006', '-gcp', '6053', '7006', '5374', '7690', '-gcp', '5642', '7013', '5374', '7376', '-gcp', '5231', '7019', '5374', '7061', '-gcp', '4821', '7026', '5374', '6746', '-gcp', '4410', '7032', '5374', '6430', '-gcp', '3999', '7039', '5374', '6116', '-gcp', '3177', '7052', '5374', '5486', '-gcp', '2765', '7060', '5374', '5170', '-gcp', '2354', '7067', '5374', '4855', '-gcp', '1944', '7072', '5374', '4541', '-gcp', '1534', '7078', '5374', '4226', '-gcp', '6892', '8054', '6186', '8320', '-gcp', '6481', '8061', '6186', '8006', '-gcp', '6071', '8068', '6186', '7691', '-gcp', '5660', '8075', '6186', '7375', '-gcp', '5250', '8081', '6186', '7060', '-gcp', '4839', '808 ...
# gdalwarp -order 2 ../sample/b04d/histology_translated.tif ../sample/b04d/histology_aligned.tif
# Error executing gdal_translate: Command '['gdalwarp', '-order 2', '../sample/b04d/histology_translated.tif', '../sample/b04d/histology_aligned.tif']' died with <Signals.SIGABRT: 6>.
# dyld[93731]: Library not loaded: /opt/homebrew/opt/libtiff/lib/libtiff.5.dylib
#   Referenced from: <0CAB49EB-EF79-36B6-A94D-C6319A10CEF5> /opt/homebrew/Cellar/libgeotiff/1.7.1_2/lib/libgeotiff.5.dylib
#   Reason: tried: '/opt/homebrew/opt/libtiff/lib/libtiff.5.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/opt/homebrew/opt/libtiff/lib/libtiff.5.dylib' (no such file), '/opt/homebrew/opt/libtiff/lib/libtiff.5.dylib' (no such file), '/usr/local/lib/libtiff.5.dylib' (no such file), '/usr/lib/libtiff.5.dylib' (no such file, not in dyld cache), '/opt/homebrew/Cellar/libtiff/4.5.1/lib/libtiff.5.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/opt/homebrew/Cellar/libtiff/4.5.1/lib/libtiff.5.dylib' (no such file), '/opt/homebrew/Cellar/libtiff/4.5.1/lib/libtiff.5.dylib' (no such file), '/usr/local/lib/libtiff.5.dylib' (no such file), '/usr/lib/libtiff.5.dylib' (no such file, not in dyld cache)Library not loaded: /opt/homebrew/opt/hdf5/lib/libhdf5_hl.200.dylib
#   Referenced from: <43F452C4-D7EF-334E-8698-DBD4E6870EEE> /opt/homebrew/Cellar/netcdf/4.9.2/lib/libnetcdf.19.dylib
#   Reason: tried: '/opt/homebrew/opt/hdf5/lib/libhdf5_hl.200.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/opt/homebrew/opt/hdf5/lib/libhdf5_hl.200.dylib' (no such file), '/opt/homebrew/opt/hdf5/lib/libhdf5_hl.200.dylib' (no such file), '/usr/local/lib/libhdf5_hl.200.dylib' (no such file), '/usr/lib/libhdf5_hl.200.dylib' (no such file, not in dyld cache), '/opt/homebrew/Cellar/hdf5/1.14.2/lib/libhdf5_hl.200.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/opt/homebrew/Cellar/hdf5/1.14.2/lib/libhdf5_hl.200.dylib' (no such file), '/opt/homebrew/Cellar/hdf5/1.14.2/lib/libhdf5_hl.200.dylib' (no such file), '/usr/local/lib/libhdf5_hl.200.dylib' (no such file), '/usr/lib/libhdf5_hl.200.dylib' (no such file, not in dyld cache)
# dyld[93733]: Library not loaded: /opt/homebrew/opt/libtiff/lib/libtiff.5.dylib
#   Referenced from: <0CAB49EB-EF79-36B6-A94D-C6319A10CEF5> /opt/homebrew/Cellar/libgeotiff/1.7.1_2/lib/libgeotiff.5.dylib
#   Reason: tried: '/opt/homebrew/opt/libtiff/lib/libtiff.5.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/opt/homebrew/opt/libtiff/lib/libtiff.5.dylib' (no such file), '/opt/homebrew/opt/libtiff/lib/libtiff.5.dylib' (no such file), '/usr/local/lib/libtiff.5.dylib' (no such file), '/usr/lib/libtiff.5.dylib' (no such file, not in dyld cache), '/opt/homebrew/Cellar/libtiff/4.5.1/lib/libtiff.5.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/opt/homebrew/Cellar/libtiff/4.5.1/lib/libtiff.5.dylib' (no such file), '/opt/homebrew/Cellar/libtiff/4.5.1/lib/libtiff.5.dylib' (no such file), '/usr/local/lib/libtiff.5.dylib' (no such file), '/usr/lib/libtiff.5.dylib' (no such file, not in dyld cache)Library not loaded: /opt/homebrew/opt/hdf5/lib/libhdf5_hl.200.dylib
#   Referenced from: <43F452C4-D7EF-334E-8698-DBD4E6870EEE> /opt/homebrew/Cellar/netcdf/4.9.2/lib/libnetcdf.19.dylib
#   Reason: tried: '/opt/homebrew/opt/hdf5/lib/libhdf5_hl.200.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/opt/homebrew/opt/hdf5/lib/libhdf5_hl.200.dylib' (no such file), '/opt/homebrew/opt/hdf5/lib/libhdf5_hl.200.dylib' (no such file), '/usr/local/lib/libhdf5_hl.200.dylib' (no such file), '/usr/lib/libhdf5_hl.200.dylib' (no such file, not in dyld cache), '/opt/homebrew/Cellar/hdf5/1.14.2/lib/libhdf5_hl.200.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/opt/homebrew/Cellar/hdf5/1.14.2/lib/libhdf5_hl.200.dylib' (no such file), '/opt/homebrew/Cellar/hdf5/1.14.2/lib/libhdf5_hl.200.dylib' (no such file), '/usr/local/lib/libhdf5_hl.200.dylib' (no such file), '/usr/lib/libhdf5_hl.200.dylib' (no such file, not in dyld cache)
